# %%
import pandas as pd
import numpy as np

movies = pd.read_csv("movies.csv")
ipl  = pd.read_csv("ipl-matches.csv")
print(movies)
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# sum
list =[
    [100,90,10],
    [110,100,15],
    [90,89,8],
    [95,90,12]
]

df1 = pd.DataFrame(list,columns=["Iq","Marks","Package"])
print(df1)

print(df1.sum(axis=1))

# 1-row
# 0-column
# Out:
#     Iq  Marks  Package
# 0  100     90       10
# 1  110    100       15
# 2   90     89        8
# 3   95     90       12
# 0    200
# 1    225
# 2    187
# 3    197
# dtype: int64

# %%
print(df1.mean())
print(df1.min())
print(df1.max())
print(df1.std())
print(df1.var())
print(df1.median())
# Out:
# Iq         98.75
# Marks      92.25
# Package    11.25
# dtype: float64
# Iq         90
# Marks      89
# Package     8
# dtype: int64
# Iq         110
# Marks      100
# Package     15
# dtype: int64
# Iq         8.539126
# Marks      5.188127
# Package    2.986079
# dtype: float64
# Iq         72.916667
# Marks      26.916667
# Package     8.916667
# dtype: float64
# Iq         97.5
# Marks      90.0
# Package    11.0
# dtype: float64

# %%
# selecting columns from dataframe

name = movies['title_x']
print(name)
print(type(name))
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object
# <class 'pandas.core.series.Series'>

# %%
print(ipl['Venue'])
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# selecting multiple columns

# jist order mein mangaya hai - usi order mein aayega
print((movies[['title_x','year_of_release','actors']]))
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
print(ipl[['Team1','Team2',"WinningTeam"]])
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
# fetching rows

stud_data = {
    "name":['Hardik',"Rohan","Jyoti","Ashish","Kartik","Lavanya"],
    "iq":[100,90,95,89,110,120],
    "marks":[80,70,100,50,90,95],
    "package":[10,7,8,9,11,12]
}

stud = pd.DataFrame(stud_data)
stud.set_index('name', inplace=True)
print(stud)
# Out:
#           iq  marks  package
# name
# Hardik   100     80       10
# Rohan     90     70        7
# Jyoti     95    100        8
# Ashish    89     50        9
# Kartik   110     90       11
# Lavanya  120     95       12

# %%
# selecting a single row - iloc
movies.iloc[4]
# Out:
# title_x                                               Evening Shadows
# imdb_id                                                     tt6028796
# poster_path                                                       NaN
# wiki_link               https://en.wikipedia.org/wiki/Evening_Shadows
# title_y                                               Evening Shadows
# original_title                                        Evening Shadows
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                           102
# genres                                                          Drama
# imdb_rating                                                       7.3
# imdb_votes                                                        280
# story               While gay rights and marriage equality has bee...
# ...

# %%
# multiple rows

# iloc mein last index is exclusive

movies.iloc[0:5]
movies.iloc[0:15:3]
# Out:
#                      title_x    imdb_id  \
# 0   Uri: The Surgical Strike  tt8291224
# 3            Why Cheat India  tt8108208
# 6              Fraud Saiyaan  tt5013008
# 9           Thackeray (film)  tt7777196
# 12                 Hum Chaar  tt9319812
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 3   https://upload.wikimedia.org/wikipedia/en/thum...
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 3       https://en.wikipedia.org/wiki/Why_Cheat_India
# 6         https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 9      https://en.wikipedia.org/wiki/Thackeray_(film)
# 12            https://en.wikipedia.org/wiki/Hum_Chaar
#
# ...

# %%
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# selecting by label - loc

stud.loc['Hardik']

# loc mein last index is included

stud.loc['Hardik':'Lavanya':2]

# fancy indexing
stud.loc[['Hardik','Lavanya']]
# Out:
#          iq  marks  package
# name
# Hardik  100     80       10
# Jyoti    95    100        8
# Kartik  110     90       11

# %%
# selecting both rows and columns

#  i want the firt 3 rows and 3 columns only
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
# important

# filtering out the data from the dataframe

# on ipl data

# find all the winner
mask = ipl['MatchNumber']=='Final'
ndf = ipl[mask]

ndf[["Season","WinningTeam"]]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many matches have gone into super over
sup = ipl['SuperOver']=='Y'
ipl[sup].shape[0]
# Out:
# 14

# %%
# how many macthes csk won in kolkata
match =ipl[(ipl['City']=='Kolkata')&(ipl['WinningTeam']=='Chennai Super Kings')]
print(match)
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
match = ipl[(ipl['TossWinner']==ipl['WinningTeam'])]
match.shape[0]/ipl.shape[0] * 100
# Out:
# 51.473684210526315

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies[(movies["imdb_rating"]>8) & (movies["imdb_votes"]>10000)].shape[0]
# Out:
# 43

# %%
mask1 = ( movies['genres'].str.split('|').apply(lambda x:"Action" in x))
# mask2 = (movies['genres'].str.contains('Action'))
movies[(movies['imdb_rating']>7.5) & mask1 ]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
def win (str1,str2):
    win1 = ipl[(ipl['Team1']==str1) & (ipl['Team2']==str2) & (ipl['WinningTeam']==str1)].shape[0]
    win2 = ipl[(ipl['Team1']==str1) & (ipl['Team2']==str2) & (ipl['WinningTeam']==str2)].shape[0]
    
    return win1,win2

st1 = input("enter the name of first team")
st2 = input("Enter the second team")
win(st1,st2)
# Out:
# (9, 12)

# %%
# how to add a new column
movies['country'] = 'India'
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies['LeadActor'] = movies['actors'].str.split("|").apply(lambda x : x[0])

# %%
#  change the type of columns - astype

ipl['Season'] = ipl["Season"].astype("category")
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
