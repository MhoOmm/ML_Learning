# %%
import pandas as pd 
import numpy as np

subs = pd.read_csv("subs.csv").squeeze("columns")

# len
print(len(subs))
# type
print(type(subs))
# dir
# print(dir(subs))

# sorted

# min
print(subs.min())#pandas inbuilt
print(min(subs))#python built
# max
# Out:
# 365
# <class 'pandas.core.series.Series'>
# 33
# 33
