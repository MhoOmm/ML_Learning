# %%
import pandas as pd
import numpy as np

# with one column

# print(pd.read_csv("subs.csv")) # converts into a dataframe

pd.read_csv("subs.csv", header=None).squeeze("columns")
# Out:
# 0      Subscribers gained
# 1                      48
# 2                      57
# 3                      40
# 4                      43
#               ...
# 361                   231
# 362                   226
# 363                   155
# 364                   144
# 365                   172
# Name: 0, Length: 366, dtype: object

# %%
# two columns

runs = pd.read_csv("kohli_ipl.csv",index_col="match_no").squeeze("columns")
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movie = pd.read_csv("bollywood.csv",index_col="movie").squeeze("columns")
print(movie)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# function of series

# HEad and tail
movie.head()
movie.head(10)

movie.tail()

# sample - pure dataset mein ek random value aajayega
movie.sample()
# movie.sample(10)
# Out:
# movie
# Thodi Life Thoda Magic    Saahil Chadha
# Name: lead, dtype: object

# %%
movie = pd.read_csv("bollywood.csv",index_col="movie").squeeze("columns")
# print(movie)

# koi value ka value counts - value_counts
print(movie.value_counts())
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64
# lead
# Akshay Kumar        0.032000
# Amitabh Bachchan    0.030000
# Ajay Devgn          0.025333
# Salman Khan         0.020667
# Sanjay Dutt         0.017333
#                       ...
# Diganth             0.000667
# Parveen Kaur        0.000667
# Seema Azmi          0.000667
# Akanksha Puri       0.000667
# Edwin Fernandes     0.000667
# Name: proportion, Length: 566, dtype: float64

# %%
runs = pd.read_csv("kohli_ipl.csv",index_col="match_no").squeeze("columns")
runs.sort_values(ascending=False).head(1).values #method chaining
# Out:
# array([113])

# %%
# inplace sorting ( permanent)
runs1 = pd.read_csv("kohli_ipl.csv",index_col="match_no").squeeze("columns")
# runs1.sort_values(inplace=True)

# %%
# sort index to sort the indexes

runs.sort_index()
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
#
