# %%
marks = int(input("Enter your marks"))
if(marks>=90):
    print("Grade : O")
elif(marks >=80):
    print("Grade : E")
elif(marks >=70):
    print("Grade : A")
elif (marks >=60):
    print("Grade : B")
else:
    print("fail")
# Out:
# Grade : E
