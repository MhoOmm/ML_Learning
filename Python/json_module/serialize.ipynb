# %%
import json
l = [1,2,3,4,5,7]
with open("sample.txt","w") as f:
    json.dump(l,f)
    f.write("\n")

# %%
import json
with open("sample.txt","r") as f:
    print(json.load(f))
# Out:
# [1, 2, 3, 4, 5, 7]

# %%
import json
t = (1,2,3,4,5,7) # tuple ko store nhi kar sakte 
# it gets stored as a list only
with open("sample1.txt","w") as f:
    json.dump(t,f)
    f.write("\n")
