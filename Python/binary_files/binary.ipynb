# %%
with open("skrillex.webp","rb") as f:
    with open("democopy.webp","wb") as d:
        d.write(f.read())

with open("skrillex.webp","rb") as f:
        print(f.read())
# Out:
# b'RIFFJ\x7f\x00\x00WEBPVP8X\n\x00\x00\x00\x10\x00\x00\x007\x04\x00^\x02\x00ALPH\xaa\x00\x00\x00\x01/ \x10H\xfc\xa1?\x8d\x88\x08&(h$5BB\xd1\x82\x014\xd4\xbf\xa9\x7f"\xfa?\x01\xb53\xce\xd8\x19;w\xc6\x8e\x8dqz\xcb\x9d\xb1cg\xec\xda\x19\'VP8 z~\x00\x000\xee\x01\x9d\x01*8\x04_\x02>Q$\x90F\xa3\xa1\xa1\xa1\xa218\xf8p\n\tgn\x95y\xbc\'\xd7v\x19\xd9\x95\xf34\x17\xf5\x1f\xf9< \xff\x83\xa9\xcbD\xff\xc9\xea\x03\xf9_\xf8o;\xf9V\xa3\x7f\x8a/\xe9\xf3\x7f\xff\xa3\xca\x07\xedX\x9e\xcc\xef5j\x12!l\xf0\xad\xbb\xcf\xa7l\xbb\xb4\x9a\xd6\x
# ...
