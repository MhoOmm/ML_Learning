# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("placement.csv")
df.head()

plt.scatter(df['cgpa'],df['package'])
plt.xlabel('Cgpa')
plt.ylabel('package in lakhs')
# Out:
# Text(0, 0.5, 'package in lakhs')

# %%
X = df.iloc[:,0:1]
Y = df.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train,Y_train)
lr.predict(X_test.iloc[0].values.reshape(1,1))
# the best fit line 
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color = 'red')
plt.xlabel('Cgpa')
plt.ylabel('package in lakhs')
# Out:
# c:\Users\KIIT0001\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Text(0, 0.5, 'package in lakhs')

# %%
# mae

from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
Y_pred = lr.predict(X_test)

# %%
Y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
err = mean_absolute_error(Y_test,Y_pred)
print("MAE:",err)
# Out:
# MAE: 0.2884710931878175

# %%
print("MSE:",mean_squared_error(Y_test,Y_pred))
print("RMSE:",np.sqrt(mean_squared_error(Y_test,Y_pred)))
# Out:
# MSE: 0.12129235313495527
# RMSE: 0.34827051717731616

# %%
# R2 score

print("R2 score",r2_score(Y_test,Y_pred))

# adjusted R2 score
r2 = r2_score(Y_test,Y_pred)
radj = 1-((1-r2)*(40-1)/(40-2))
print("r2 adjusted",radj)
# Out:
# R2 score 0.780730147510384
# r2 adjusted 0.7749598882343415
