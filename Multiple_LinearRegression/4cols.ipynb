# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.datasets import make_regression

x,y = make_regression(n_samples=200,n_features=3,n_informative=3,n_targets=1,noise=50)

df = pd.DataFrame({'feat1':x[:,0],'feat2':x[:,1],'feat3':x[:,2],'target':y})
df.head()
# Out:
#       feat1     feat2     feat3      target
# 0 -1.121603 -0.704112  1.009447  -18.744695
# 1  0.534184  0.250880  0.154172  -14.202977
# 2 -0.248016  1.007096  0.721708  136.462761
# 3 -0.203469  0.325138 -1.585044  -64.039648
# 4  0.583782  0.244709 -0.531600  -10.954668

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=3)

Y_test
# Out:
# array([-119.29317253,  -34.04310636,  209.72318732,   62.752051  ,
#          29.6293368 , -125.41505069, -148.1711162 ,  193.40797939,
#        -248.09329016,  -32.37626287,    4.68631162,  -86.03994199,
#        -122.6813809 ,  -77.05039468,   -5.41011192,  -77.34371061,
#          53.1519359 ,  -64.03964757, -138.58006507,  -61.04201656,
#         -84.80912658,  -75.01996929,  -32.29581075,   63.69893522,
#        -174.72830445,  113.83893503,   39.54710647,   31.74260661,
#         -63.19476891, -171.26312318, -129.98317226,  142.44283334,
#        -204.08786595,   60.92840028,   -1.33380008,  -98.90409306,
#         -10.9546683 ,   47.0787239 ,   79.58599845,  209.96998782])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train,Y_train)

y_pred = lr.predict(X_test)

y_pred
# Out:
# array([ -98.02315997,  -74.53230016,  184.40017573,   24.80181346,
#          36.26732621,  -16.78861304, -102.53975649,  122.52402259,
#        -226.75340446,  -14.24494682,  -33.06674763,   -2.6913123 ,
#        -149.24622193, -105.74176316,  -86.080808  ,  -50.10944571,
#          16.94480313,  -79.23920423, -131.05874284,   -9.77604679,
#          25.88566644,  -86.01042453, -115.7368558 ,   63.67918281,
#        -113.43023554,   89.10703659,   77.51862177,   19.18376469,
#         -69.62159532, -192.44333604,  -61.34291233,   47.24534554,
#        -149.72645652,   65.08364267,   36.59925269,  -83.05596246,
#          20.02419394,   97.20351289,   97.03831749,  192.96952287])

# %%
print("Mae:",mean_absolute_error(Y_test,y_pred))
print("Mse:",mean_squared_error(Y_test,y_pred))
print("r2:",r2_score(Y_test,y_pred))
# Out:
# Mae: 38.793641733554516
# Mse: 2339.569361143126
# r2: 0.8055663552354151
