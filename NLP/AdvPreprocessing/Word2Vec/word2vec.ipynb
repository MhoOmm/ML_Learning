# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %%
import gensim.downloader as api
model = api.load("word2vec-google-news-300")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import gensim.downloader as api
# ----> 2 model = api.load("word2vec-google-news-300")
#
# File c:\Users\KIIT0001\miniconda3\Lib\site-packages\gensim\downloader.py:503, in load(name, return_path)
#     501 sys.path.insert(0, BASE_DIR)
#     502 module = __import__(name)
# --> 503 return module.load_data()
#
# File ~/gensim-data\word2vec-google-news-300\__init__.py:8, in load_data()
#       6 def load_data():
#       7     path = os.path.join(base_dir, 'word2vec-google-news-300', "word2vec-google-news-300.gz")
# ----> 8     model = KeyedVectors.load_word2vec_format(path, binary=True)
#       9     return model
#
# File c:\Users\KIIT0001\miniconda3\Lib\site-packages\gensim\models\keyedvectors.py:1721, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1674 @classmethod
#    1675 def load_word2vec_format(
#    1676         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1677         limit=None, datatype=REAL, no_header=False,
#    1678     ):
#    1679     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1680
#    1681     Warnings
#    (...)   1719
#    1720     """
# -> 1721     return _load_word2vec_format(
#    1722         cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1723         limit=limit, datatype=datatype, no_header=no_header,
#    1724     )
#
# File c:\Users\KIIT0001\miniconda3\Lib\site-packages\gensim\models\keyedvectors.py:2067, in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2064 kv = cls(vector_size, vocab_size, dtype=datatype)
#    2066 if binary:
# -> 2067     _word2vec_read_binary(
#    2068         fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding
#    2069     )
#    2070 else:
#    2071     _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#
# File c:\Users\KIIT0001\miniconda3\Lib\site-packages\gensim\models\keyedvectors.py:1960, in _word2vec_read_binary(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size, encoding)
#    1957 tot_processed_words = 0
#    1959 while tot_processed_words < vocab_size:
# -> 1960     new_chunk = fin.read(binary_chunk_size)
#    1961     chunk += new_chunk
#    1962     processed_words, chunk = _add_bytes_to_kv(
#    1963         kv, counts, chunk, vocab_size, vector_size, datatype, unicode_errors, encoding)
#
# File c:\Users\KIIT0001\miniconda3\Lib\gzip.py:340, in GzipFile.read(self, size)
#     338     import errno
#     339     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 340 return self._buffer.read(size)
#
# File c:\Users\KIIT0001\miniconda3\Lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File c:\Users\KIIT0001\miniconda3\Lib\gzip.py:554, in _GzipReader.read(self, size)
#     552 if self._decompressor.needs_input:
#     553     buf = self._fp.read(READ_BUFFER_SIZE)
# --> 554     uncompress = self._decompressor.decompress(buf, size)
#     555 else:
#     556     uncompress = self._decompressor.decompress(b"", size)
#
# KeyboardInterrupt:

# %%
# Check the vector for a word
print(model['king'][:10])  # first 10 dimensions

# Most similar words
print(model.most_similar('king', topn=5))

# Word analogy example: king - man + woman ≈ queen
print(model.most_similar(positive=['king', 'woman'], negative=['man'], topn=1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Check the vector for a word
# ----> 2 print(model['king'][:10])  # first 10 dimensions
#       4 # Most similar words
#       5 print(model.most_similar('king', topn=5))
#
# NameError: name 'model' is not defined
