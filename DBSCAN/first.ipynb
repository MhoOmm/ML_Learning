# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles
X, _ = make_circles(n_samples=500, factor=.5, noise=.03, random_state=4)

# %%
plt.scatter(X[:,0],X[:,1])
plt.title("DBSCAN Clustering of Concentric Circles")
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
# Out:
# Text(0, 0.5, 'Feature 1')

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(min_samples=4,eps=0.2)
y_pred = db.fit_predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("DBSCAN Clustering of Concentric Circles")
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show()

# %%
from sklearn.datasets import make_moons
mX,_ = make_moons(n_samples=500, noise=0.05, random_state=30)

plt.scatter(mX[:,0],mX[:,1])

# %%
cluster = db.fit_predict(mX)
plt.scatter(mX[:,0],mX[:,1],c=cluster)
